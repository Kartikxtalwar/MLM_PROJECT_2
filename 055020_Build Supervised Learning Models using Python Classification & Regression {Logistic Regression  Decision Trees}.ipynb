# %% [markdown]
# <a href="https://colab.research.google.com/github/ShefaliDhingra/MLM_Supervised_Learning_055043/blob/main/MLM_Project_043.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Supervised Learning Models for Classification & Regression: Predicting Import-Export Dynamics
# ---

# %% [markdown]
# ## PROJECT CONTENTS:
#
# 1. Project Information
# 2. Description of Data
# 3. Data Sampling
# 4. Project Objectives | Problem Statements
# 5. Analysis of Data
# 6. Observations | Findings
# 7. Managerial Insights | Recommendations
#
# ---

# %% [markdown]
# ## 1. Project Information
# * Student : **Kartik Talwar (055020)**
#
# ---

# %% [markdown]
# ## 2. Description of Data
#
#  Data Source: [Dataset link](https://drive.google.com/file/d/1CaNQK-TaN13c-p1gkx6dkGEY8h2k8Vi7/view?usp=sharing
# )
#
#  ***A live link is used in the dataset***

# %% [markdown]
# ### Data Columns Description:
#
# 1. Transaction_ID: Unique identifier for each trade transaction.
# 2. Country: Country of origin or destination for the trade.
# 3. Product: Product being traded.
# 4. Import_Export: Indicates whether the transaction is an import or export.
# 5. Quantity: Amount of the product traded.
# 6. Value: Monetary value of the product in USD.
# 7. Date: Date of the transaction.
# 8. Category: Category of the product (e.g., Electronics, Clothing, Machinery).
# 9. Port: Port of entry or departure.
# 10. Customs_Code: Customs or HS code for product classification.
# 11. Weight: Weight of the product in kilograms.
# 12. Shipping_Method: Method used for shipping (e.g., Air, Sea, Land).
# 13. Supplier: Name of the supplier or manufacturer.
# 14. Customer: Name of the customer or recipient.
# 15. Invoice_Number: Unique invoice number for the transaction.
# 16. Payment_Terms: Terms of payment (e.g., Net 30, Net 60, Cash on Delivery).

# %% [markdown]
# Data Type: Since the dataset contains multiple entities (countries) and records data over time, this is an example of **Panel Data** (also called longitudinal data)

# %% [markdown]
# ### Data Variables
# As observed, the dataset contains:
# 1. **All** non-null Variables
# 2. Numbers:
#     1. Interger Variables: **3**  (*Quantity, Customs_Code, Invoice_Number*)
#     2. Float (Decimal) Variables: **2**  (*Value, Weight*)
# 3. Text: **9**  (*Country, Product, Import_Export, Category, Port, Shipping_Method, Supplier, Customer, Payment_Terms*)
# 4. DateTime: **1** (*Date*)
#
# ---

# %% [markdown]
# ## 3. Data Sampling
#
# From the Dataset containing 15,000 values, a sample of 5001 entries were taken. The dataset sample (now refered as kt_20_sample) was taken into account for further exploration. To match with the project objectives, a new column was added to the sample dataset called **Total Value** which represented the product of value of the product and it's quantity Imported/Exported.

# %% [markdown]
# ### Data Variables
# My_sample dataset consists of follwing Nominal, Ordinal and Non-Categorical Data as follows:
# 1. Index_variables are 'Transaction_ID' and 'Invoice_Number'
# 2. Categorical Variables:
#     - Nominal_Variables are 'Country','Product','Category','Port','Customer','Supplier','Customs_Code'
#     - Ordinal_variables are 'Payment_Terms','Shipping_Method','Import_Export'
# 3. Non_Categorical_Variables are Quantity, Value, Total Value and Weight
#
# ---

# %% [markdown]
# ### About the Dataset
#
# This dataset provides detailed information on international trade transactions, capturing both import and export activities. It includes comprehensive data on various aspects of trade, making it a valuable resource for business analysis, economic research, and financial modeling.
# The Dataset used in this project is a stored in a google drive which can be viewed by anyone.
#
# Data Format: The dataset is provided in CSV format, making it easy to load into data analysis tools and frameworks.
#
# Additional Notes:
# The dataset consists of 15,000 rows and the sample taken consits of 5001 rows, ensuring a substantial sample size for meaningful analysis.
# Data is generated with realistic variability, simulating actual trade transactions.

# %% [markdown]
# ## 4. Project Objectives
#
# - Classification of Dataset into {Segments | Clusters | Classes} using Supervised Learning Classification Algorithms
# - Identification of {Important | Contributing | Significant} Variables or Features and their Thresholds for Classification
# - Determination of an appropriate Classification Model based on Performance Metrics
#
#
# ---

# %% [markdown]
# ## 5. Exploratory Data Analysis
#
# ### 5.1. Data Preprocessing:
#
# - Treatment of Missing Data
# - Numerical Encoding of Non-Numeric Categorical Data
# Re-Scaling & Transformation of Numeric Data (Treatment of
# Data having Outliers)
# - Standardization | Normalization (Min-Max Scaling) | Log
# Transformation
#
# ### 5.2. Descriptive Statistics
# Primarily the data was split into Categorical and Non-Categorical variables for Analysis. The analysis carried forward was as follows:
# - Non-Categorical Variables:
#     1. Measures of Central Tendency {Minimum | Maximum | Mean | Median | Mode | Percentile
#     2. Measures of Dispersion {Range | Standard Deviation | Skewness | Kurtosis | Correlation (Matrix) }
#     3. Composite Measure {Coefficient of Variation | Confidence Interval}
#
# - Categorical Variables:
#
#     1. Count | Frequency | Proportion | Minimum | Maximum | Mode | Rank
#
# ### 5.3 Data Visualisation
#
# Various Subplots were used such as Bar, Heatmaps, Histograms and Co-relation Matrices
#
# ### 5.4 Inferential Statistics
#
# - Categorical Variable [Nominal | Ordinal]
#   - Test of Homogeneity {Chi-sq}
#
# - Non-Categorical Variable
#   - Test of Normality {Shapiro-Wilk}
#
# ### 5.5 Machine Learning Models
#
# 1. Classification & Regression
#   - Regression {Logistic (LR)} | [Others: Support Vector Machines (SVM) | Stochastic Gradient Descent (SGD)]
#   - Decision Trees (DT) | [Others: K-Nearest Neighbors (KNN) | Naive Bayes (NB)]
#   - Ensembles (Bagging | Boosting): Random Forest (RF) | Extreme Gradient Boosting (XGBoost)
#
# ### 5.6. Model Performance Metrics
#
# 1. Classification: Confusion Matrix {Sensitivity or Recall | Specificity | Accuracy | Precision | F1-Score | AUC}
# 2. Cross-Validation (K-Fold)
# 3. Model Run Statistics
#   - Time Taken
#   - Memory Used
#
# ### 5.7. Diagnostics
#
# - Classification: Identification & Importance or Relevance of Key Input Variables or Features & their Thresholds or Limits
#
# ---

# %% [markdown]
# # 6. Observations
#
# ## 6.0. Data Preprocessing
#
# - The data has no missing data present, hence no missin data treatment was performed.
# - For efficient analysis, the Ordinal data was encoded is following manner:
#
# | **Category**       | **Value**          | **Encoded** |
# |--------------------|--------------------|-------------|
# | Payment Terms      | Cash on Delivery   | 0           |
# | Payment Terms      | Net 30             | 1           |
# | Payment Terms      | Net 60             | 2           |
# | Payment Terms      | Prepaid            | 3           |
# | Shipping Method    | Air                | 0           |
# | Shipping Method    | Land               | 1           |
# | Shipping Method    | Sea                | 2           |
# | Import/Export      | Export             | 0           |
# | Import/Export      | Import             | 1           |
#
# - For encoding, `Ordinal Encoder` was used
# - Based on Shapiro-Wilk's Test of Normality, the non-normal non-categorical variables were identified. All Non-Categorical variables were found to be non-normal and hence were scaled using `Min-Max Scaler` to improve the overall accuracy of algorithms.
#
# ## 6.1. Nature of Data
#
# ### 6.1.1. Non Categorical Data:
#
# - `Range:` The values for all variables are normalized within the range of 0 to 1 (min = 0, max = 1).
# - `Mean and Median (50th Percentile)`:
#   - The mean and median values for Quantity, Value, and Weight are very close to each other, suggesting a symmetric distribution.
#   - `Total_Value has a mean of 0.258 and a median of 0.197, indicating slight positive skewness.
# - `Spread (Standard Deviation)`: The standard deviation of all variables is around 0.28, indicating a moderate level of variability in the dataset.
# - `Quartiles`:
#   - The interquartile range is consistent across Quantity, Value, and Weight, suggesting similar variability in their distributions.
#   - Total_Value has a smaller IQR compared to the other variables, indicating that most of its values are concentrated within a narrower range.
# - `Relative Variability`:
#   - Total_Value has the highest CV (86.44%), indicating it exhibits the most relative variability compared to its mean. This suggests that Total_Value values are more spread out and less consistent.
#   - Quantity, Value, and Weight have relatively similar CVs (around 57–58%), showing consistent variability across these features.
# - `Normalized Nature of Variables`: Despite all variables being normalized to a range of 0–1, Total_Value stands out with its higher CV, implying its distribution is more dispersed relative to its mean.
# - Narrow `Confidence Intervals` for Most Variables: The confidence intervals for Quantity, Value, and Weight are very narrow (approximately 0.49 to 0.50 or 0.51), reflecting high precision in the estimation of their means.
# - Broader `Confidence Interval` for Total_Value: The CI for Total_Value (0.25 to 0.26) is slightly wider relative to its mean. This is consistent with its higher Coefficient of Variation (86.44%) and standard deviation, which indicate greater relative variability and less precision in the mean estimate compared to the other variables.
# - Consistency in `Central Tendency`: The means of all variables lie well within their respective confidence intervals, reinforcing the reliability of the calculated mean values.
#
# - `Strong Positive Correlation with Total_Value`: `Quantity` and `Value` both show a strong positive correlation with `Total_Value` (0.6538 and 0.6548, respectively). This is expected as `Total_Value` is derived as the product of `Quantity` and `Value`.
#
# - `Minimal Correlation Between Quantity and Value`: The weak negative correlation (-0.0038) between `Quantity` and `Value` indicates these variables are nearly independent and do not significantly influence each other directly.
#
# - `Insignificant Role of Weight`: `Weight` shows negligible correlation with all other variables, including `Total_Value` (0.0027). This suggests that `Weight` may not contribute directly to determining `Total_Value` or interact meaningfully with `Quantity` or `Value`.
#
# - `No Multicollinearity Among Predictors`: The absence of strong correlations (near ±1) among the independent variables (`Quantity`, `Value`, and `Weight`) indicates that they do not exhibit multicollinearity, ensuring their independence for predictive modeling.
#
# ### 6.1.2 Categorical Variables:
#
# - **`Country`**:
#   - The dataset contains records from 243 unique countries.
#   - `Congo` has the highest frequency (43 occurrences, 0.86%), making it the mode.
#   - The country distribution is highly diverse, with many countries having a minimal proportion (e.g., `Micronesia` at 0.18%).
#   - The alphabetical range spans from `Afghanistan` to `Zimbabwe`.
#
# - **`Product`**:
#   - There are 968 unique products, with `green` and `family` having the highest frequency (14 occurrences each, 0.28%).
#   - The mode is `family`, and the alphabetical range extends from `American` to `yourself`.
#   - A significant proportion of products (most with 0.02% frequency) appear only once, suggesting a long tail distribution.
#
# - **`Category`**:
#   - The dataset has five product categories, with `Clothing` as the most frequent (1084 occurrences, 21.68%).
#   - `Toys` has the lowest proportion (18.66%).
#   - The mode is `Clothing`, with a clear and balanced distribution across categories.
#
# - **`Port`**:
#   - There are 4326 unique ports, indicating high diversity.
#   - `Michaelland` and `South David` share the highest frequency (8 occurrences, 0.16%).
#   - Most ports occur only once, resulting in a long-tail distribution.
#   - The alphabetical range is from `Aaronborough` to `Zhangborough`.
#
# - **`Customer`**:
#   - There are 4844 unique customers.
#   - `Michael Williams`, `Michelle Smith`, and `Robert Moore` are the most frequent customers, each appearing 4 times (0.08%).
#   - The mode is `Michael Williams`, and the alphabetical range is from `Aaron Ayers` to `Zachary Taylor`.
#
# - **`Supplier`**:
#   - There are 4573 unique suppliers.
#   - `Johnson PLC` appears most frequently (10 occurrences, 0.20%), making it the mode.
#   - A large number of suppliers (most with 0.02% frequency) appear only once.
#   - The alphabetical range is from `Abbott and Sons` to `Zuniga, Perez and Martin`.
#
# - **`Customs_Code`**:
#   - The dataset contains 4989 unique customs codes.
#   - The mode is `177147`, occurring twice (0.04%).
#   - Most customs codes (4985 of 5001) appear only once, indicating almost entirely unique entries.
#   - The numerical range spans from `100171` to `999964`.
#
# - **`Payment_Terms`**:
#   - There are four unique payment terms.
#   - `0.0` is the most common, occurring 1296 times (25.91%), making it the mode.
#   - Payment terms are distributed relatively evenly across the dataset.
#
# - **`Shipping_Method`**:
#   - There are three unique shipping methods.
#   - `2.0` is the most common, appearing 1728 times (34.55%), making it the mode.
#   - The distribution across methods is relatively balanced, with a slight preference for method `2.0`.
#
# - **`Import_Export`**:
#   - There are two unique values, `0.0` (Import) and `1.0` (Export).
#   - `0.0` is slightly more frequent (2519 occurrences, 50.37%), making it the mode.
#   - The sample 055043 random state is nearly evenly split between imports and exports.
#
# - `Spearman Correlation`:
#   - Country vs. Port (0.019013): Weak positive correlation.
#   - Category vs. Port (0.036265): Slightly stronger but still weak positive correlation.
#   - Payment Terms vs. Import/Export (0.027576): Weak positive correlation suggests a slight association between payment terms and whether the transaction is an import or export.
#   - Shipping Method vs. Import/Export (-0.039698): Weak negative correlation implies a slight tendency for different shipping methods to be associated with import/export status.
# - `Kendall Correlation`:
#   - The trends mirror the Spearman correlations but with generally smaller magnitudes, as Kendall's tau is more conservative:
#   - Country vs. Port (0.012924): Slight positive association.
#   - Category vs. Port (0.026512): Weak positive association.
#   - Payment Terms vs. Import/Export (0.025175): Similar positive relationship as in Spearman.
# - `Categorical Variables Correlations`:
#   - Correlations are generally weak across all variables, suggesting minimal linear or monotonic relationships.
#   - The strongest (but still weak) correlations are seen between Category and Port, indicating some possible patterns worth exploring further.
#   - Variables like Shipping Method and Import/Export have weak negative correlations with several others, which might suggest inverse associations.
#
# ### 6.1.3. Inferential Statistics:
#
# - **Country, Product, Category, Port, Customer, Supplier, Customs_Code, and Payment_Terms** did not show a significant relationship with Import_Export.
# - Shipping_Method has a significant association with Import_Export and was retained as a relevant feature for analysis.
#
# - Based on above analysis, `'Country', 'Product', 'Category', 'Port', 'Customer', 'Supplier', 'Customs_Code'` were **dropped** from the dataset for further analysis.
#
# -------------------
# ## 6.2. Supervised Machine Learning: Classification & Regression
#
# - To compare and contrast various algorithms, `Lazy Predict` Library was used. The result was as follows:
#
# | Model                           | Accuracy | Balanced Accuracy | ROC AUC | F1 Score | Time Taken |
# |---------------------------------|---------|-------------------|---------|----------|------------|
# | LGBMClassifier                  | 0.54    | 0.54              | 0.54    | 0.54     | 0.24       |
# | Perceptron                      | 0.54    | 0.54              | 0.54    | 0.53     | 0.03       |
# | BaggingClassifier               | 0.54    | 0.53              | 0.53    | 0.53     | 1.03       |
# | QuadraticDiscriminantAnalysis   | 0.53    | 0.53              | 0.53    | 0.53     | 0.03       |
# | SGDClassifier                   | 0.53    | 0.53              | 0.53    | 0.53     | 0.09       |
# | BernoulliNB                     | 0.53    | 0.53              | 0.53    | 0.53     | 0.06       |
# | CalibratedClassifierCV          | 0.52    | 0.52              | 0.52    | 0.52     | 0.21       |
# | SVC                             | 0.52    | 0.52              | 0.52    | 0.52     | 1.30       |
# | KNeighborsClassifier            | 0.52    | 0.52              | 0.52    | 0.52     | 0.20       |
# | GaussianNB                      | 0.52    | 0.52              | 0.52    | 0.52     | 0.04       |
# | LogisticRegression              | 0.52    | 0.52              | 0.52    | 0.52     | 0.05       |
# | LinearDiscriminantAnalysis      | 0.52    | 0.52              | 0.52    | 0.52     | 0.09       |
# | LabelSpreading                  | 0.52    | 0.52              | 0.52    | 0.52     | 1.40       |
# | RidgeClassifierCV               | 0.52    | 0.51              | 0.51    | 0.51     | 0.09       |
# | RidgeClassifier                 | 0.52    | 0.51              | 0.51    | 0.51     | 0.03       |
# | LinearSVC                       | 0.52    | 0.51              | 0.51    | 0.51     | 0.08       |
# | RandomForestClassifier          | 0.52    | 0.51              | 0.51    | 0.51     | 1.38       |
# | NearestCentroid                 | 0.51    | 0.51              | 0.51    | 0.51     | 0.08       |
# | ExtraTreesClassifier            | 0.51    | 0.51              | 0.51    | 0.51     | 1.35       |
# | AdaBoostClassifier              | 0.51    | 0.51              | 0.51    | 0.51     | 1.18       |
# | LabelPropagation                | 0.51    | 0.51              | 0.51    | 0.51     | 0.77       |
# | DecisionTreeClassifier          | 0.51    | 0.51              | 0.51    | 0.51     | 0.24       |
# | NuSVC                           | 0.50    | 0.50              | 0.50    | 0.50     | 4.71       |
# | DummyClassifier                 | 0.51    | 0.50              | 0.50    | 0.34     | 0.06       |
# | PassiveAggressiveClassifier     | 0.48    | 0.49              | 0.49    | 0.41     | 0.03       |
# | ExtraTreeClassifier             | 0.48    | 0.48              | 0.48    | 0.48     | 0.08       |
#
# ### 6.2.1 Determination of Appropriate Classification Model
#
# *Comparison Based on Performance Metrics:*
#
# - **Logistic Regression (LR)**:
#   - **Cross-validation scores**: [0.5034965, 0.503, 0.504, 0.496, 0.496]
#   - **Average Cross-validation score**: 0.5005
#   - **Important Features**: No significant features identified
#   - **Conclusion**: Logistic Regression performed with moderate consistency across folds but did not identify important features for further optimization.
#
# - **Decision Tree (DT)**:
#   - **Cross-validation scores**: [0.4995005, 0.493, 0.523, 0.501, 0.516]
#   - **Average Cross-validation score**: 0.5065
#   - **Important Features**:
#
# | Feature            | Importance |
#     |--------------------|------------|
#     | Invoice_Number     | 0.21       |
#     | Weight             | 0.21       |
#     | Value              | 0.18       |
#     | Total_Value        | 0.17       |
#     | Quantity           | 0.16       |
#     | Payment_Terms      | 0.06       |
#
#   - **Conclusion**: Decision Tree showed moderate consistency and identified several important features that could help improve performance.
#
# - **Random Forest (RF)**:
#   - **Cross-validation scores**: [0.53846154, 0.539, 0.503, 0.513, 0.517]
#   - **Average Cross-validation score**: 0.5221
#   - **Important Features**:
#
# | Feature            | Importance |
#     |--------------------|------------|
#     | Invoice_Number     | 0.19       |
#     | Weight             | 0.19       |
#     | Value              | 0.18       |
#     | Quantity           | 0.18       |
#     | Total_Value        | 0.18       |
#
#   - **Thresholds**: Thresholds > 0.7 considered for high importance features
#   - **Conclusion**: Random Forest showed good performance and identified key features such as Invoice Number, Weight, and Value, which are crucial for further optimization.
#
# - **K-Nearest Neighbors (KNN)**:
#   - **Cross-validation scores**: [0.51348651, 0.505, 0.505, 0.483, 0.505]
#   - **Average Cross-validation score**: 0.5023
#   - **Conclusion**: KNN showed relatively stable performance across folds, but it did not identify any significant features based on permutation importance.
#
# - **Support Vector Machine (SVM)**:
#   - **Cross-validation scores**: [0.50949051, 0.509, 0.476, 0.493, 0.51]
#   - **Average Cross-validation score**: 0.4995
#   - **Important Features**: No significant features identified (empty list).
#   - **Conclusion**: SVM performed with moderate consistency but did not yield significant features for optimization.
#
#
# ### 6.2.2. Cross-Validation of Results and Performance for Classification Models
#
# - Cross-validation was performed to validate the consistency of results and performance across all models:
#
#   - **Logistic Regression**: Achieved moderate consistency but no significant features for improvement.
#   - **Decision Tree**: Showed reasonable stability with identified important features (Invoice Number, Weight, Value, etc.).
#   - **Random Forest**: Performed well with consistent results and identified critical features such as Invoice Number and Weight.
#   - **KNN**: No significant features were found, but the model showed stable results.
#   - **SVM**: Similar performance to Logistic Regression with no significant features.
#
#
# ### 6.2.3. Identification of Important Variables or Features and Their Thresholds
#
# #### 1. **Logistic Regression (LR)**:
# - **Important Features**: No significant features were identified.
# - **Threshold**: Standard threshold of 0.5 for classification.
#
# #### 2. **Decision Tree (DT)**:
# - **Important Features**: Invoice Number, Weight, Value, Total Value, Quantity, and Payment Terms.
# - **Threshold**: Decision Trees adaptively set thresholds based on feature splits.
#
# #### 3. **Random Forest (RF)**:
# - **Important Features**: Invoice Number, Weight, Value, Quantity, Total Value.
# - **Thresholds**: High importance features (Invoice Number, Weight, etc.) should have a threshold > 0.7 for optimization.
#
# #### 4. **K-Nearest Neighbors (KNN)**:
# - **Important Features**: No significant features were identified through permutation importance.
# - **Threshold**: KNN dynamically adjusts based on nearest neighbors.
#
# #### 5. **Support Vector Machine (SVM)**:
# - **Important Features**: No significant features identified.
# - **Threshold**: Threshold of 0.1 for classification.
#
# ---
#
# ## Summary of Observations | Findings for Supervised Learning Models
#
# - **Best Overall Performance**: Random Forest and Decision Tree models showed strong performance with consistent cross-validation scores and important features.
# - **Best for Feature Interpretation**: Decision Tree provides clear insight into feature importance, making it highly interpretable.
# - **Best Stability**: Random Forest demonstrated a more stable performance across folds, with key features influencing predictions.

# %% [markdown]
# # 7. Managerial Insights

# %% [markdown]
# ## 7.1. Preprocessing of Data
#
# 1. Recommended Treatment of Missing Data
# - As the dataset has no missing data, no treatment was required
#
# 2. Recommended Numerical Encoding of Non-Numeric Categorical Data
# - Ordinal encoding was used for categorical variables like 'Payment Terms' and 'Shipping Method' which have a natural order.
# - For non-ordinal categorical data (e.g., Country, Product), One-Hot Encoding could be considered to avoid introducing artificial ordering
# - The following encoding schemes were used for ordinal data:
#   - Payment Terms: Cash on Delivery (0), Net 30 (1), Net 60 (2), Prepaid (3)
#   - Shipping Method: Air (0), Land (1), Sea (2)
#   - Import/Export: Export (0), Import (1)
#
# - When encoding non-ordinal data, we can in future consider One-Hot Encoding for nominal variables.
#
# 3. Recommended Treatment of Non-Categorical Numeric Data having Non-Uniform Scales & Outliers
#   - Non-categorical numeric data like Quantity, Value, Weight, and Total_Value were normalized using Min-Max scaling.
#   - Min-Max Scaling transformed the data within the range of 0 to 1, improving the performance of many machine learning algorithms.
#   - Outliers should be handled separately by using techniques like IQR (Interquartile Range) or Z-score methods, depending on their impact on model accuracy.
#   - A log transformation can also be considered if skewness in the data is significant, especially for features like Total_Value which exhibit a positive skew.
#
# 4. Recommended Split of Sample Data into Training & Testing Sets
#   - The data should be split into a training and testing set using a 70:30 or 80:20 split for better generalization. (for this project, a 80:20 split was considered)
#   - A random split ensures the data is randomly distributed, while stratified sampling may be better suited for classification tasks where the distribution of the target variable is imbalanced.
#   - Stratified sampling ensures the proportion of classes is maintained in both training and testing datasets, improving model robustness.
#
# ## 7.2. Supervised Machine Learning: Classification & Regression
#
# 1. Inference Regarding the Purpose of Classification
#   - The goal of classification in this context is to predict the Import/Export status of transactions based on various factors like Payment Terms, Shipping Method, and other key variables.
#   - Classification is crucial when the target variable is categorical, and the objective is to categorize new observations into predefined classes.
#
# 2. For each Classification Model, Recommendation of Key Features and Their Thresholds
#
#   - Decision Tree:
#     - Key Features: Invoice Number, Weight, Value, Total_Value, Quantity, Payment Terms.
#     - Thresholds: Decision Trees adaptively set thresholds for classification. However, features like 'Invoice Number' and 'Weight' were identified as having high importance, with thresholds > 0.7 for optimization.
#
#   - Random Forest:
#     - Key Features: Invoice Number, Weight, Value, Quantity, Total_Value.
#     - Thresholds: Features with importance greater than 0.7, such as 'Invoice Number' and 'Weight', should be prioritized for optimization to improve model accuracy.
#
#   - Logistic Regression:
#     - Key Features: None were identified as significant in this analysis. Logistic Regression performed with moderate consistency but didn't highlight useful features for improvement.
#
#   - K-Nearest Neighbors (KNN):
#     - Key Features: No significant features were identified based on permutation importance.
#     - Thresholds: KNN is a non-parametric method that adapts dynamically based on the nearest neighbors.
#
#   - Support Vector Machine (SVM):
#     - Key Features: No significant features were identified in this model.
#     - Thresholds: Standard threshold of 0.5 for classification.
#
# 3. Considering the Nature of the Data, for each Classification Model, Insight on Its Uniqueness, Usability and Suitability
#
# - Decision Tree:
#   - Uniqueness: Decision Trees provide clear and interpretable insights into feature importance, making them suitable for understanding the decision-making process.
#   - Usability: Decision Trees are simple to implement and interpret, but they may suffer from overfitting with very deep trees.
#   - Suitability: Decision Trees work well for datasets with complex interactions between features. They are ideal when interpretability and understanding feature importance are important.
#
# - Random Forest:
#   - Uniqueness: Random Forest is an ensemble method that combines multiple Decision Trees to improve accuracy and reduce overfitting.
#   - Usability: Random Forest is highly effective for improving accuracy and generalization compared to individual Decision Trees.
#   - Suitability: Random Forest is well-suited for datasets with many features and when accuracy is the primary concern. However, it can be less interpretable than Decision Trees.
#
# - Logistic Regression:
#   - Uniqueness: Logistic Regression is a simple and widely used algorithm for binary classification tasks.
#   - Usability: It's easy to implement and fast to train. However, it assumes linear relationships between features and may not perform well on complex datasets.
#   - Suitability: Suitable for situations where the data has a linear decision boundary. It's not ideal for datasets with complex non-linear relationships between features.
#
# - K-Nearest Neighbors (KNN):
#   - Uniqueness: KNN is a non-parametric method that makes predictions based on the distance to the nearest neighbors.
#   - Usability: KNN can be computationally expensive, especially for large datasets. It also struggles with high-dimensional data.
#   - Suitability: KNN is suitable for small to medium-sized datasets with simple relationships. It is not ideal for large datasets or datasets with high-dimensional features.
#
# - Support Vector Machine (SVM):
#   - Uniqueness: SVM is a powerful classifier that maximizes the margin between classes, making it effective for high-dimensional data.
#   - Usability: SVM can be computationally expensive, especially with large datasets. It also requires careful tuning of hyperparameters (kernel, C, gamma).
#   - Suitability: SVM is suitable for datasets with clear margins of separation and is often used for image recognition and text classification tasks.
#
# Overall,
#   - Random Forest and Decision Tree provide the best performance with clear feature importance, making them suitable for tasks requiring interpretability.
#   - Logistic Regression and SVM may not provide much insight into feature importance and can be less effective on this dataset.
#   - KNN can be useful in simpler, smaller datasets but is less suitable for this data.

# %% [markdown]
# --- End of Report ---

# %% [markdown]
# ## Project Information

# %%
# Import Relevant Python Libraries

import io
import requests
import pandas as pd
import statsmodels.formula.api as sm
import scipy.stats as stats
from scipy.stats import chi2_contingency
from scipy.stats import shapiro, kstest, anderson, jarque_bera
from scipy.cluster.hierarchy import dendrogram, linkage
import statsmodels.stats.descriptivestats as dstats
import numpy as np
from sklearn.impute import SimpleImputer  # For Imputation of Missing Data
from sklearn.preprocessing import OrdinalEncoder  # For Encoding Categorical Data [Nominal | Ordinal]
from sklearn.preprocessing import StandardScaler, MinMaxScaler # For Rescaling Data
from sklearn.model_selection import train_test_split  # For Splitting Data into Training & Testing Sets
import matplotlib.pyplot as plt
import seaborn as sns  # For Data Visualization
import statsmodels.api as sm
from sklearn import metrics
import scipy.stats as stats
import statsmodels.stats.multicomp as multi
import warnings
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
# !pip install lazypredict

import lazypredict
from lazypredict.Supervised import LazyClassifier, LazyRegressor
from lazypredict.Supervised import LazyRegressor
from sklearn.inspection import permutation_importance
warnings.filterwarnings('ignore')

# %%
pip install dask[dataframe]

# %%
import requests
import pandas as pd
import io

# Extract the file ID from the Google Drive link
file_id = "1CaNQK-TaN13c-p1gkx6dkGEY8h2k8Vi7"
url = f"https://drive.google.com/uc?id={file_id}"

# Send a GET request to the URL
response = requests.get(url)

# Read the CSV data into a pandas DataFrame
kt_20_df = pd.read_csv(io.StringIO(response.text))

# Display the first few rows of the DataFrame
print(kt_20_df.head())
# Out:
#                          Transaction_ID           Country    Product  \
# 0  e3e70682-c209-4cac-a29f-6fbed82c07cd          Colombia   describe
# 1  f728b4fa-4248-4e3a-8a5d-2f346baa9455             Chile  president
# 2  eb1167b3-67a9-4378-bc65-c1e582e2e662            Turkey        far
# 3  f7c1bd87-4da5-4709-9471-3d60c8a70639  Christmas Island     agency
# 4  e443df78-9558-467f-9ba9-1faf7a024204           Finland     policy
#
#   Import_Export  Quantity   Value        Date     Category              Port  \
# 0        Export      1979 9506.57  07-12-2023    Machinery        Robertbury
# 1        Export      5763 7100.91  04-04-2023     Clothing          Shahport
# 2        Import      5740 2450.34  21-08-2024  Electronics  South Joshuatown
# 3        Export      2592 7226.42  09-05-2022    Furniture          Adamfort
# 4        Export      2622 2817.29  03-04-2023  Electronics         Juliebury
#
#    Customs_Code  Weight Shipping_Method                         Supplier  \
# ...

# %%
# Adding a Total_Value variable
kt_20_df['Total_Value'] = round(kt_20_df['Value'] * kt_20_df['Quantity'], 0)
kt_20_df.head(3)
# Out:
#                          Transaction_ID   Country    Product Import_Export  \
# 0  e3e70682-c209-4cac-a29f-6fbed82c07cd  Colombia   describe        Export
# 1  f728b4fa-4248-4e3a-8a5d-2f346baa9455     Chile  president        Export
# 2  eb1167b3-67a9-4378-bc65-c1e582e2e662    Turkey        far        Import
#
#    Quantity   Value        Date     Category              Port  Customs_Code  \
# 0      1979 9506.57  07-12-2023    Machinery        Robertbury        620537
# 1      5763 7100.91  04-04-2023     Clothing          Shahport        927600
# 2      5740 2450.34  21-08-2024  Electronics  South Joshuatown        299258
#
#    Weight Shipping_Method                         Supplier       Customer  \
# 0 4248.65             Air  Garrison, Hubbard and Hendricks      Seth Hall
# 1 4340.81             Air                        Webb-Mack  Kimberly Ryan
# 2 4538.41             Air        Mendez, Jones and Johnson     Ryan Silva
#
#    Invoice_Number     Payment_Terms  Total_Value
# ...

# %%
# Data Dimensions
print("The dimensions of the data are: ", kt_20_df.shape)
# Out:
# The dimensions of the data are:  (15000, 17)

# %%
# Data Variable Type
kt_20_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Transaction_ID   15000 non-null  object
#  1   Country          15000 non-null  object
#  2   Product          15000 non-null  object
#  3   Import_Export    15000 non-null  object
#  4   Quantity         15000 non-null  int64
#  5   Value            15000 non-null  float64
#  6   Date             15000 non-null  object
#  7   Category         15000 non-null  object
#  8   Port             15000 non-null  object
#  9   Customs_Code     15000 non-null  int64
#  10  Weight           15000 non-null  float64
#  11  Shipping_Method  15000 non-null  object
#  12  Supplier         15000 non-null  object
#  13  Customer         15000 non-null  object
#  14  Invoice_Number   15000 non-null  int64
#  15  Payment_Terms    15000 non-null  object
# ...

# %%
# Columns in the dataset

kt_20_variables = list(kt_20_df.columns)
print("The Variables are:", kt_20_variables)
# Out:
# The Variables are: ['Transaction_ID', 'Country', 'Product', 'Import_Export', 'Quantity', 'Value', 'Date', 'Category', 'Port', 'Customs_Code', 'Weight', 'Shipping_Method', 'Supplier', 'Customer', 'Invoice_Number', 'Payment_Terms', 'Total_Value']

# %%
# Bifurcating the Variables into Index, Categorical (Nominal, Ordinal) and Non-Categorical Variables

kt_20_index_vars = ['Transaction_ID', 'Invoice_Number']
kt_20_nominal_vars = ['Country', 'Product', 'Category', 'Port', 'Customer', 'Supplier', 'Customs_Code']
kt_20_ordinal_vars = ['Payment_Terms', 'Shipping_Method', 'Import_Export']

kt_20_cat_vars = kt_20_nominal_vars + kt_20_ordinal_vars
kt_20_non_cat_vars = ['Quantity', 'Value', 'Weight', 'Total_Value']

# %%
# Data Types

print("Data Types:")
print(kt_20_df.dtypes)
# Out:
# Data Types:
# Transaction_ID      object
# Country             object
# Product             object
# Import_Export       object
# Quantity             int64
# Value              float64
# Date                object
# Category            object
# Port                object
# Customs_Code         int64
# Weight             float64
# Shipping_Method     object
# Supplier            object
# Customer            object
# Invoice_Number       int64
# Payment_Terms       object
# Total_Value        float64
# dtype: object

# %% [markdown]
# ## Data Sampling

# %%
# A Unique Sample of 5001 Records
kt_20_random_state = 55020
kt_20_sample = pd.DataFrame.sample(kt_20_df, n=5001, random_state=kt_20_random_state, ignore_index=False)

# %%
# Displaying the Dimensions of Sample Data.
kt_20_sample.shape
# Out:
# (5001, 17)

# %% [markdown]
# ## Data Preprocessing

# %%
kt_20_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5001 entries, 2407 to 5569
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Transaction_ID   5001 non-null   object
#  1   Country          5001 non-null   object
#  2   Product          5001 non-null   object
#  3   Import_Export    5001 non-null   object
#  4   Quantity         5001 non-null   int64
#  5   Value            5001 non-null   float64
#  6   Date             5001 non-null   object
#  7   Category         5001 non-null   object
#  8   Port             5001 non-null   object
#  9   Customs_Code     5001 non-null   int64
#  10  Weight           5001 non-null   float64
#  11  Shipping_Method  5001 non-null   object
#  12  Supplier         5001 non-null   object
#  13  Customer         5001 non-null   object
#  14  Invoice_Number   5001 non-null   int64
#  15  Payment_Terms    5001 non-null   object
# ...

# %%
# Check for missing values

kt_20_sample.isnull().sum(axis=1)
# Out:
# 2407     0
# 5021     0
# 4605     0
# 11017    0
# 12207    0
#         ..
# 7650     0
# 11912    0
# 5327     0
# 9207     0
# 5569     0
# Length: 5001, dtype: int64

# %% [markdown]
# ### This shows that our code has no missing data, hence we would be skipping the missing data treatment

# %%
# Encoding

# Select categorical columns with text data
kt_20_categorical_cols_text = kt_20_sample[kt_20_ordinal_vars].select_dtypes(include=['object']).columns

# Create OrdinalEncoder
kt_20_encoder = OrdinalEncoder()

# Fit and transform encoder on selected columns
kt_20_ds_cat_encoded = kt_20_sample[kt_20_ordinal_vars].copy()  # Create a copy to avoid modifying the original
kt_20_ds_cat_encoded[kt_20_categorical_cols_text] = kt_20_encoder.fit_transform(kt_20_sample[kt_20_categorical_cols_text])

# Display encoded dataset
print("\nEncoded Categorical Dataset:")
kt_20_ds_cat_encoded.head()
# Out:
# Encoded Categorical Dataset:
#        Payment_Terms  Shipping_Method  Import_Export
# 2407            1.00             0.00           1.00
# 5021            1.00             2.00           0.00
# 4605            2.00             2.00           1.00
# 11017           2.00             0.00           0.00
# 12207           2.00             2.00           0.00

# %%
# Display encoding mapping

for col in kt_20_categorical_cols_text:
    print(f"\nEncoding Mapping for {col}:")
    for i, category in enumerate(kt_20_encoder.categories_[kt_20_categorical_cols_text.get_loc(col)]):
        print(f"{category} -> {i}")
# Out:
# Encoding Mapping for Payment_Terms:
# Cash on Delivery -> 0
# Net 30 -> 1
# Net 60 -> 2
# Prepaid -> 3
#
# Encoding Mapping for Shipping_Method:
# Air -> 0
# Land -> 1
# Sea -> 2
#
# Encoding Mapping for Import_Export:
# Export -> 0
# Import -> 1

# %%
# Check normality using Shapiro-Wilk test
kt_20_normality_results = {}
for col in kt_20_non_cat_vars:
    _, p_value = shapiro(kt_20_sample[col])
    kt_20_normality_results[col] = p_value

# Identify non-normally distributed variables
kt_20_non_normal_vars = [col for col, p_value in kt_20_normality_results.items() if p_value < 0.05]
kt_20_non_normal_vars
# Out:
# ['Quantity', 'Value', 'Weight', 'Total_Value']

# %%
# Scale non-normally distributed variables using MinMaxScaler
kt_20_scaler = MinMaxScaler()
kt_20_ds_noncat_scaled = kt_20_sample[kt_20_non_cat_vars].copy()  # Create a copy to avoid modifying the original
kt_20_ds_noncat_scaled[kt_20_non_normal_vars] = kt_20_scaler.fit_transform(kt_20_ds_noncat_scaled[kt_20_non_normal_vars])

# Display scaled variables
print("\nVariables that were scaled:")
print(kt_20_non_normal_vars)

# Display scaled dataset
print("\nScaled Non-Categorical Dataset:")
kt_20_ds_noncat_scaled.head()
# Out:
# Variables that were scaled:
# ['Quantity', 'Value', 'Weight', 'Total_Value']
#
# Scaled Non-Categorical Dataset:
#        Quantity  Value  Weight  Total_Value
# 2407       0.93   0.40    0.89         0.38
# 5021       0.91   0.38    0.56         0.36
# 4605       0.66   0.04    0.72         0.03
# 11017      0.35   0.02    0.74         0.01
# 12207      0.37   0.70    0.25         0.26

# %%
# The pre-processed Dataset
kt_20_processed = pd.concat([kt_20_sample[kt_20_index_vars], kt_20_ds_cat_encoded, kt_20_ds_noncat_scaled, kt_20_sample[kt_20_nominal_vars]], axis=1)
kt_20_processed.head()
# Out:
#                              Transaction_ID  Invoice_Number  Payment_Terms  \
# 2407   92931f54-4dca-41c1-aa1f-7a9391340a41         7748664           1.00
# 5021   9d486bf1-914c-475a-b3cd-5e52eaf68027        33084263           1.00
# 4605   5de95471-4d60-4cc6-82f9-91676a71a0e5        58456025           2.00
# 11017  17d737c9-65da-4d27-8562-6be92b52308f        60567165           2.00
# 12207  7b2b45c0-7d6c-4f1e-aa22-6fbbe75b6190        80468789           2.00
#
#        Shipping_Method  Import_Export  Quantity  Value  Weight  Total_Value  \
# 2407              0.00           1.00      0.93   0.40    0.89         0.38
# 5021              2.00           0.00      0.91   0.38    0.56         0.36
# 4605              2.00           1.00      0.66   0.04    0.72         0.03
# 11017             0.00           0.00      0.35   0.02    0.74         0.01
# 12207             2.00           0.00      0.37   0.70    0.25         0.26
#
# ...

# %%
# new sample shape

kt_20_sample.shape
# Out:
# (5001, 17)

# %% [markdown]
# ---

# %% [markdown]
# ## Descriptive Statistics

# %% [markdown]
# ### Non-Categorical Variables

# %%
kt_20_processed[kt_20_non_cat_vars].describe()
# Out:
#        Quantity   Value  Weight  Total_Value
# count   5001.00 5001.00 5001.00      5001.00
# mean       0.50    0.50    0.50         0.26
# std        0.29    0.29    0.29         0.22
# min        0.00    0.00    0.00         0.00
# 25%        0.25    0.25    0.25         0.07
# 50%        0.49    0.50    0.49         0.19
# 75%        0.74    0.75    0.75         0.39
# max        1.00    1.00    1.00         1.00

# %%
# Coefficient of Variation
def coefficient_of_variation(data):
    mean = data.mean()
    std = data.std()
    cv = (std / mean) * 100
    return cv

cv_results = {}

for col in kt_20_non_cat_vars:
    cv_results[col] = coefficient_of_variation(kt_20_processed[col])

# Display the results
print("Coefficient of Variation (%):")
for col, cv in cv_results.items():
    print(f"{col}: {cv:.2f}%")
# Out:
# Coefficient of Variation (%):
# Quantity: 57.77%
# Value: 57.80%
# Weight: 58.08%
# Total_Value: 87.40%

# %%
# Confidence Interval for the Mean
def confidence_interval(data, confidence=0.95):
    mean = data.mean()
    std = data.std()
    n = len(data)
    z = stats.norm.ppf(1 - (1 - confidence) / 2)  # z-score for 95% CI
    margin_of_error = z * (std / np.sqrt(n))
    lower_bound = mean - margin_of_error
    upper_bound = mean + margin_of_error
    return (lower_bound, upper_bound)

kt_20_ci_results = {}

for col in kt_20_non_cat_vars:
    kt_20_ci_results[col] = confidence_interval(kt_20_processed[col])

print("\nConfidence Intervals (95%):")
for col, ci in kt_20_ci_results.items():
    print(f"{col}: {ci[0]:.2f} to {ci[1]:.2f}")
# Out:
# Confidence Intervals (95%):
# Quantity: 0.49 to 0.50
# Value: 0.49 to 0.51
# Weight: 0.49 to 0.51
# Total_Value: 0.25 to 0.26

# %%
correlation_data = kt_20_processed[kt_20_non_cat_vars]
correlation_matrix = correlation_data.corr()
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#              Quantity  Value  Weight  Total_Value
# Quantity         1.00   0.02    0.02         0.67
# Value            0.02   1.00    0.00         0.66
# Weight           0.02   0.00    1.00         0.01
# Total_Value      0.67   0.66    0.01         1.00

# %%
plt.figure(figsize=(8, 5))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# ### Categorical

# %%
# Frequency, proportion, minimum, maximum, and mode for categorical variables
categorical_summary = {}
for col in kt_20_cat_vars:
    summary = {}
    summary['Count'] = kt_20_processed[col].value_counts().sum()
    summary['Frequency'] = kt_20_processed[col].value_counts()
    summary['Proportion'] = kt_20_processed[col].value_counts(normalize=True)
    summary['Minimum'] = kt_20_processed[col].min()
    summary['Maximum'] = kt_20_processed[col].max()
    summary['Mode'] = kt_20_processed[col].mode()[0]  # Get the first mode if multiple exist

    categorical_summary[col] = summary

# Print the summary
for col, summary in categorical_summary.items():
    print(f"Summary for {col}:")
    print(f"  Count: {summary['Count']}")
    print(f"  Frequency: \n{summary['Frequency']}")
    print(f"  Proportion:\n{summary['Proportion']}")
    print(f"  Minimum: {summary['Minimum']}")
    print(f"  Maximum: {summary['Maximum']}")
    print(f"  Mode: {summary['Mode']}")
    print("-" * 20)
# Out:
# Summary for Country:
#   Count: 5001
#   Frequency:
# Country
# Korea             46
# Congo             41
# Tajikistan        32
# Gambia            31
# American Samoa    31
#                   ..
# Gibraltar         12
# Fiji              12
# Georgia           10
# Belgium           10
# Seychelles         8
# Name: count, Length: 243, dtype: int64
#   Proportion:
# Country
# Korea            0.01
# Congo            0.01
# Tajikistan       0.01
# Gambia           0.01
# American Samoa   0.01
#                  ...
# Gibraltar        0.00
# Fiji             0.00
# Georgia          0.00
# Belgium          0.00
# Seychelles       0.00
# Name: proportion, Length: 243, dtype: float64
#   Minimum: Afghanistan
#   Maximum: Zimbabwe
#   Mode: Korea
# --------------------
# Summary for Product:
#   Count: 5001
#   Frequency:
# Product
# public    15
# effect    13
# bank      13
# change    13
# music     12
#           ..
# too        1
# father     1
# voice      1
# figure     1
# ...

# %%
def categorical_correlation_matrix(df, columns, method='spearman'):
    """
    Creates a correlation matrix for categorical variables using Spearman or Kendall method.
    """
    correlation_matrix = pd.DataFrame(index=columns, columns=columns)
    for col1 in columns:
        for col2 in columns:
            if col1 == col2:
                correlation_matrix.loc[col1, col2] = 1.0  # Set diagonal to 1
            else:
                # Handle potential errors with invalid input for spearmanr
                try:
                    if method == 'spearman':
                        correlation, _ = stats.spearmanr(df[col1], df[col2])
                    elif method == 'kendall':
                        correlation, _ = stats.kendalltau(df[col1], df[col2])
                    else:
                        raise ValueError(
                            "Invalid correlation method. Use 'spearman' or 'kendall'.")
                    correlation_matrix.loc[col1, col2] = correlation
                    correlation_matrix.loc[col2, col1] = correlation  # Ensure symmetry
                except ValueError:
                    # Handle cases where spearmanr fails (e.g., non-numeric data)
                    correlation_matrix.loc[col1, col2] = np.nan
                    correlation_matrix.loc[col2, col1] = np.nan

    # Convert the matrix to numeric if possible, otherwise handle non-numeric values
    correlation_matrix = correlation_matrix.apply(pd.to_numeric, errors='coerce').fillna(0)

    return correlation_matrix


# Example usage (replace with your DataFrame and columns)
categorical_cols = kt_20_cat_vars  # Update with your actual categorical column names
spearman_corr_matrix = categorical_correlation_matrix(
    kt_20_processed, categorical_cols, method='spearman')
kendall_corr_matrix = categorical_correlation_matrix(
    kt_20_processed, categorical_cols, method='kendall')

print("Spearman Correlation Matrix:")
print(spearman_corr_matrix)

print("\nKendall Correlation Matrix:")
print(kendall_corr_matrix)
# Out:
# Spearman Correlation Matrix:
#                  Country  Product  Category  Port  Customer  Supplier  \
# Country             1.00    -0.03      0.00  0.02      0.01      0.01
# Product            -0.03     1.00      0.00 -0.01      0.01      0.01
# Category            0.00     0.00      1.00  0.01      0.00      0.01
# Port                0.02    -0.01      0.01  1.00      0.02     -0.01
# Customer            0.01     0.01      0.00  0.02      1.00     -0.02
# Supplier            0.01     0.01      0.01 -0.01     -0.02      1.00
# Customs_Code        0.02     0.01     -0.00  0.02      0.01     -0.00
# Payment_Terms      -0.01    -0.02     -0.00 -0.00      0.01     -0.00
# Shipping_Method    -0.01    -0.00     -0.01  0.01      0.04     -0.00
# Import_Export      -0.02    -0.00     -0.00 -0.01      0.00     -0.01
#
#                  Customs_Code  Payment_Terms  Shipping_Method  Import_Export
# Country                  0.02          -0.01            -0.01          -0.02
# ...

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(spearman_corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Spearman Correlation Matrix Heatmap for Categorical Variables')
plt.show()

# %% [markdown]
# ### Data Visualisation

# %%
# Box plots for non-categorical variables

plt.figure(figsize=(15, 10))
for i, col in enumerate(kt_20_non_cat_vars):
    plt.subplot(2, 3, i + 1)
    sns.boxplot(y=kt_20_processed[col])
    plt.title(f'Box Plot of {col}')
plt.tight_layout()
plt.show()

# %%
# Histograms with KDE for distribution visualization
plt.figure(figsize=(15, 10))
for i, col in enumerate(kt_20_non_cat_vars):
    plt.subplot(2, 3, i + 1)
    sns.histplot(kt_20_processed[col], kde=True)
    plt.title(f'Distribution of {col}')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Inferential Statistics

# %%
for col in kt_20_cat_vars:
    contingency_table = pd.crosstab(kt_20_sample[col], kt_20_processed['Import_Export'])

    # Perform Chi-square test
    chi2, p, dof, expected = chi2_contingency(contingency_table)

    print(f"Chi-square test for {col} and Import_Export:")
    print(f"Chi-square statistic: {chi2}")
    print(f"P-value: {p}")
    print(f"Degrees of freedom: {dof}")

    # Interpret results
    alpha = 0.05
    if p < alpha:
        print("Reject the null hypothesis: There is a significant association between", col, "and Import_Export.")
    else:
        print("There is no significant association between", col, "and Import_Export.")
    print("-" * 20)
# Out:
# Chi-square test for Country and Import_Export:
# Chi-square statistic: 216.73310224632408
# P-value: 0.8770796589833324
# Degrees of freedom: 242
# There is no significant association between Country and Import_Export.
# --------------------
# Chi-square test for Product and Import_Export:
# Chi-square statistic: 932.8799378437305
# P-value: 0.7439146929012661
# Degrees of freedom: 962
# There is no significant association between Product and Import_Export.
# --------------------
# Chi-square test for Category and Import_Export:
# Chi-square statistic: 3.1552577115121423
# P-value: 0.5321877557493263
# Degrees of freedom: 4
# There is no significant association between Category and Import_Export.
# --------------------
# Chi-square test for Port and Import_Export:
# Chi-square statistic: 4300.997395090913
# P-value: 0.4201989150217073
# Degrees of freedom: 4283
# There is no significant association between Port and Import_Export.
# --------------------
# ...

# %% [markdown]
# ## Dataset Optimisation

# %%
# Drop insignificant columns
columns_to_drop = ['Country', 'Product', 'Category', 'Port', 'Customer', 'Supplier','Transaction_ID','Customs_Code']
kt_20_processed = kt_20_processed.drop(columns=columns_to_drop)
kt_20_processed.head()
# Out:
#        Invoice_Number  Payment_Terms  Shipping_Method  Import_Export  \
# 2407          7748664           1.00             0.00           1.00
# 5021         33084263           1.00             2.00           0.00
# 4605         58456025           2.00             2.00           1.00
# 11017        60567165           2.00             0.00           0.00
# 12207        80468789           2.00             2.00           0.00
#
#        Quantity  Value  Weight  Total_Value
# 2407       0.93   0.40    0.89         0.38
# 5021       0.91   0.38    0.56         0.36
# 4605       0.66   0.04    0.72         0.03
# 11017      0.35   0.02    0.74         0.01
# 12207      0.37   0.70    0.25         0.26

# %% [markdown]
# # Supervised Machine Learning

# %% [markdown]
# ## Data Splitting

# %%
X = kt_20_processed.drop('Import_Export', axis=1)
y = kt_20_processed['Import_Export']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=kt_20_random_state)

# Print the shapes of the resulting datasets
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (4000, 7)
# X_test shape: (1001, 7)
# y_train shape: (4000,)
# y_test shape: (1001,)

# %% [markdown]
# ## Classification

# %%
# LazyClassifier for Classification
clf = LazyClassifier()
models_classification, predictions_classification = clf.fit(X_train, X_test, y_train, y_test)

# Display the classification models and their performance
print(models_classification)
# Out:
# 100%|██████████| 32/32 [00:28<00:00,  1.13it/s]
# [LightGBM] [Info] Number of positive: 1973, number of negative: 2027
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000562 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1284
# [LightGBM] [Info] Number of data points in the train set: 4000, number of used features: 7
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.493250 -> initscore=-0.027002
# [LightGBM] [Info] Start training from score -0.027002
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LabelPropagation                   0.54               0.54     0.54      0.54
# LabelSpreading                     0.54               0.54     0.54      0.54
# PassiveAggressiveClassifier        0.53               0.53     0.53      0.50
# KNeighborsClassifier               0.53               0.53     0.53      0.53
# ...

# %% [markdown]
# ## Regression

# %%
# LazyRegressor for Regression
reg = LazyRegressor()
models_regression, predictions_regression = reg.fit(X_train, X_test, y_train, y_test)

# Display the regression models and their performance
models_regression
# Out:
# 100%|██████████| 42/42 [00:32<00:00,  1.28it/s]
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000321 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1284
# [LightGBM] [Info] Number of data points in the train set: 4000, number of used features: 7
# [LightGBM] [Info] Start training from score 0.493250
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# OrthogonalMatchingPursuitCV                 -0.01       0.00  0.50        0.07
# OrthogonalMatchingPursuit                   -0.01       0.00  0.50        0.03
# NuSVR                                       -0.01      -0.00  0.50       11.71
# LassoLarsIC                                 -0.01      -0.00  0.50        0.07
# LassoLars                                   -0.01      -0.00  0.50        0.05
# LassoCV                                     -0.01      -0.00  0.50        0.18
# ...

# %% [markdown]
# ## Logistic Regression

# %%
logreg_classifier = LogisticRegression(random_state=kt_20_random_state)

# Train the model
logreg_classifier.fit(X_train, y_train)

# Make predictions on the test set
y_pred_logreg = logreg_classifier.predict(X_test)

# Evaluate the model
accuracy_logreg = accuracy_score(y_test, y_pred_logreg)
print(f"Logistic Regression Accuracy: {accuracy_logreg}")
print(classification_report(y_test, y_pred_logreg))
# Out:
# Logistic Regression Accuracy: 0.4935064935064935
#               precision    recall  f1-score   support
#
#          0.0       0.49      1.00      0.66       494
#          1.0       0.00      0.00      0.00       507
#
#     accuracy                           0.49      1001
#    macro avg       0.25      0.50      0.33      1001
# weighted avg       0.24      0.49      0.33      1001

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression

# Assuming logreg_classifier is already defined and trained as in the provided code
# If not, you need to re-define and train it first.

logreg_classifier = LogisticRegression(random_state=kt_20_random_state)
logreg_classifier.fit(X_train, y_train)

# Perform cross-validation
cv_scores = cross_val_score(logreg_classifier, X, y, cv=5)  # 5-fold cross-validation

# Print the cross-validation scores
print("Cross-validation scores:", cv_scores)
print("Average cross-validation score:", cv_scores.mean())
# Out:
# Cross-validation scores: [0.5044955 0.504     0.504     0.504     0.504    ]
# Average cross-validation score: 0.5040991008991009

# %%
# Confusion Matrix for Logistic Regression
cm_logreg = confusion_matrix(y_test, y_pred_logreg)

# Plot the confusion matrix for Logistic Regression
plt.figure(figsize=(8, 6))
sns.heatmap(cm_logreg, annot=True, fmt='d', cmap='Greens',  # Different colormap
            xticklabels=logreg_classifier.classes_, yticklabels=logreg_classifier.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for Logistic Regression')
plt.show()

# %%
# Calculate correlation matrix for all numerical features with 'Import_Export'
correlation_matrix = kt_20_processed.corr()['Import_Export'].abs().sort_values(ascending=False)

# Set a threshold for correlation (adjust as needed)
correlation_threshold = 0.1

# Filter for important variables based on the threshold
important_variables = correlation_matrix[correlation_matrix > correlation_threshold].index.tolist()

# Remove 'Import_Export' itself from the list
if 'Import_Export' in important_variables:
  important_variables.remove('Import_Export')

print("Important variables based on correlation with 'Import_Export':")
print(important_variables)
# Out:
# Important variables based on correlation with 'Import_Export':
# []

# %% [markdown]
# ## Decision Tree

# %%
dt_classifier = DecisionTreeClassifier(random_state=kt_20_random_state)

# Train the model
dt_classifier.fit(X_train, y_train)

# Make predictions on the test set
y_pred_dt = dt_classifier.predict(X_test)

# Evaluate the model
accuracy_dt = accuracy_score(y_test, y_pred_dt)
print(f"Decision Tree Accuracy: {accuracy_dt}")
print(classification_report(y_test, y_pred_dt))
# Out:
# Decision Tree Accuracy: 0.4885114885114885
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.52      0.50       494
#          1.0       0.49      0.46      0.48       507
#
#     accuracy                           0.49      1001
#    macro avg       0.49      0.49      0.49      1001
# weighted avg       0.49      0.49      0.49      1001

# %%
dt_classifier = DecisionTreeClassifier(random_state=kt_20_random_state)

# Train the model
dt_classifier.fit(X_train, y_train)

# Make predictions on the test set
y_pred_dt = dt_classifier.predict(X_test)

# Evaluate the model
accuracy_dt = accuracy_score(y_test, y_pred_dt)
print(f"Decision Tree Accuracy: {accuracy_dt}")
print(classification_report(y_test, y_pred_dt))
# Out:
# Decision Tree Accuracy: 0.4885114885114885
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.52      0.50       494
#          1.0       0.49      0.46      0.48       507
#
#     accuracy                           0.49      1001
#    macro avg       0.49      0.49      0.49      1001
# weighted avg       0.49      0.49      0.49      1001

# %%
dt_classifier = DecisionTreeClassifier(random_state=kt_20_random_state)
dt_classifier.fit(X_train, y_train)

# Perform cross-validation
cv_scores_dt = cross_val_score(dt_classifier, X, y, cv=5)

# Print the cross-validation scores
print("Decision Tree Cross-validation scores:", cv_scores_dt)
print("Decision Tree Average cross-validation score:", cv_scores_dt.mean())
# Out:
# Decision Tree Cross-validation scores: [0.51848152 0.52       0.521      0.513      0.485     ]
# Decision Tree Average cross-validation score: 0.5114963036963036

# %%
# Confusion matrix
kt_20_cm = confusion_matrix(y_test, y_pred_dt)

# Plot the confusion matrix using seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(kt_20_cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=dt_classifier.classes_, yticklabels=dt_classifier.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for Decision Tree')
plt.show()

# %%
feature_importances = dt_classifier.feature_importances_

# Create a DataFrame to display feature importances
feature_importance_df = pd.DataFrame({'Feature': X_train.columns, 'Importance': feature_importances})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Define a threshold (e.g., 0.05) for importance
importance_threshold = 0.05

# Filter for important features
important_features = feature_importance_df[feature_importance_df['Importance'] >= importance_threshold]

print("Important features and their importances:")
important_features
# Out:
# Important features and their importances:
#           Feature  Importance
# 0  Invoice_Number        0.22
# 4           Value        0.20
# 5          Weight        0.18
# 3        Quantity        0.16
# 6     Total_Value        0.15
# 1   Payment_Terms        0.06

# %%
# Comparision of Lr and DT

print(f"Decision Tree Accuracy: {accuracy_dt}")
print(f"Logistic Regression Accuracy: {accuracy_logreg}")

if accuracy_dt > accuracy_logreg:
    print("Decision Tree model performs better.")
elif accuracy_logreg > accuracy_dt:
    print("Logistic Regression model performs better.")
else:
    print("Both models perform equally.")
# Out:
# Decision Tree Accuracy: 0.4885114885114885
# Logistic Regression Accuracy: 0.4935064935064935
# Logistic Regression model performs better.

# %% [markdown]
# ## Random Forest

# %%
# Initialize the Random Forest Classifier
rf_classifier = RandomForestClassifier(random_state=kt_20_random_state)

# Train the model
rf_classifier.fit(X_train, y_train)

# Make predictions on the test set
y_pred_rf = rf_classifier.predict(X_test)

# Evaluate the model
accuracy_rf = accuracy_score(y_test, y_pred_rf)
print(f"Random Forest Accuracy: {accuracy_rf}")
print(classification_report(y_test, y_pred_rf))
# Out:
# Random Forest Accuracy: 0.5214785214785215
#               precision    recall  f1-score   support
#
#          0.0       0.51      0.54      0.53       494
#          1.0       0.53      0.50      0.51       507
#
#     accuracy                           0.52      1001
#    macro avg       0.52      0.52      0.52      1001
# weighted avg       0.52      0.52      0.52      1001

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier

rf_classifier = RandomForestClassifier(random_state=kt_20_random_state)

# Perform cross-validation
cv_scores_rf = cross_val_score(rf_classifier, X, y, cv=5)

# Print the cross-validation scores
print("Random Forest Cross-validation scores:", cv_scores_rf)
print("Random Forest Average cross-validation score:", cv_scores_rf.mean())
# Out:
# Random Forest Cross-validation scores: [0.5024975 0.512     0.505     0.504     0.505    ]
# Random Forest Average cross-validation score: 0.5056995004995005

# %%
kt_20_cm_rf = confusion_matrix(y_test, y_pred_rf)

# Plot the confusion matrix for Random Forest
plt.figure(figsize=(8, 6))
sns.heatmap(kt_20_cm_rf, annot=True, fmt='d', cmap='Blues',  # You can change the colormap
            xticklabels=np.unique(y_test), yticklabels=np.unique(y_test)) # changed line
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for Random Forest')
plt.show()

# %%
rf_classifier.fit(X_train, y_train)

# Get feature importances
feature_importances = rf_classifier.feature_importances_

# Create a DataFrame to display feature importances
feature_importance_df = pd.DataFrame({'Feature': X_train.columns, 'Importance': feature_importances})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Define a threshold for importance
importance_threshold = 0.05

# Filter for important features
important_features = feature_importance_df[feature_importance_df['Importance'] >= importance_threshold]

print("Important features and their importances (Random Forest):")
print(important_features)


# Example: Setting thresholds based on feature importance
for index, row in important_features.iterrows():
    feature_name = row['Feature']
    importance_value = row['Importance']

    # Example thresholding logic (replace with your desired criteria)
    if importance_value > 0.1:
        threshold = 0.7  # Example threshold value
        print(f"Feature '{feature_name}': High importance ({importance_value:.3f}), consider threshold > {threshold}")
    elif importance_value > 0.05:
        threshold = 0.5 # Example threshold value
        print(f"Feature '{feature_name}': Medium importance ({importance_value:.3f}), consider threshold > {threshold}")
    else:
        threshold = 0.2 # Example threshold value
        print(f"Feature '{feature_name}': Low importance ({importance_value:.3f}), consider threshold > {threshold}")
# Out:
# Important features and their importances (Random Forest):
#           Feature  Importance
# 5          Weight        0.19
# 0  Invoice_Number        0.19
# 4           Value        0.18
# 3        Quantity        0.18
# 6     Total_Value        0.18
# Feature 'Weight': High importance (0.188), consider threshold > 0.7
# Feature 'Invoice_Number': High importance (0.187), consider threshold > 0.7
# Feature 'Value': High importance (0.184), consider threshold > 0.7
# Feature 'Quantity': High importance (0.179), consider threshold > 0.7
# Feature 'Total_Value': High importance (0.176), consider threshold > 0.7

# %% [markdown]
# ## K-Nearest Neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Initialize the K-Nearest Neighbors Classifier
knn_classifier = KNeighborsClassifier(n_neighbors=5)

# Train the model
knn_classifier.fit(X_train, y_train)

# Make predictions on the test set
y_pred_knn = knn_classifier.predict(X_test)

# Evaluate the model
accuracy_knn = accuracy_score(y_test, y_pred_knn)
print(f"K-Nearest Neighbors Accuracy: {accuracy_knn}")
print(classification_report(y_test, y_pred_knn))
# Out:
# K-Nearest Neighbors Accuracy: 0.5024975024975025
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.51      0.50       494
#          1.0       0.51      0.49      0.50       507
#
#     accuracy                           0.50      1001
#    macro avg       0.50      0.50      0.50      1001
# weighted avg       0.50      0.50      0.50      1001

# %%
knn_classifier = KNeighborsClassifier(n_neighbors=5)

# Perform cross-validation
cv_scores_knn = cross_val_score(knn_classifier, X, y, cv=5)  # 5-fold cross-validation

# Print the cross-validation scores
print("KNN Cross-validation scores:", cv_scores_knn)
print("KNN Average cross-validation score:", cv_scores_knn.mean())
# Out:
# KNN Cross-validation scores: [0.52247752 0.508      0.503      0.504      0.513     ]
# KNN Average cross-validation score: 0.5100955044955044

# %%
# Confusion Matrix
kt_20_cm_knn = confusion_matrix(y_test, y_pred_knn)
plt.figure(figsize=(8, 6))
sns.heatmap(kt_20_cm_knn, annot=True, fmt='d', cmap='Blues',
            xticklabels=np.unique(y_test), yticklabels=np.unique(y_test))
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for K-Nearest Neighbors')
plt.show()

# %%
knn_classifier.fit(X_train, y_train)
result = permutation_importance(knn_classifier, X_test, y_test, n_repeats=10, random_state=kt_20_random_state)

# Get feature importances
importances = result.importances_mean

# Create a DataFrame for better visualization
feature_importance_df = pd.DataFrame({'Feature': X_test.columns, 'Importance': importances})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

print("Feature Importance (KNN - Permutation Importance):")
print(feature_importance_df)
# Out:
# Feature Importance (KNN - Permutation Importance):
#            Feature  Importance
# 1    Payment_Terms        0.00
# 2  Shipping_Method        0.00
# 3         Quantity        0.00
# 4            Value        0.00
# 5           Weight        0.00
# 6      Total_Value        0.00
# 0   Invoice_Number       -0.00

# %% [markdown]
# ## Support Vector Machine

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import cross_val_score

# Initialize the SVM classifier
svm_classifier = SVC(random_state=kt_20_random_state)  # You can adjust hyperparameters here

# Train the model
svm_classifier.fit(X_train, y_train)

# Make predictions on the test set
y_pred_svm = svm_classifier.predict(X_test)

# Evaluate the model
accuracy_svm = accuracy_score(y_test, y_pred_svm)
print(f"SVM Accuracy: {accuracy_svm}")
print(classification_report(y_test, y_pred_svm))
# Out:
# SVM Accuracy: 0.4855144855144855
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.51      0.49       494
#          1.0       0.49      0.46      0.48       507
#
#     accuracy                           0.49      1001
#    macro avg       0.49      0.49      0.49      1001
# weighted avg       0.49      0.49      0.49      1001

# %%
# Perform cross-validation
cv_scores_svm = cross_val_score(svm_classifier, X, y, cv=5)

# Print the cross-validation scores
print("SVM Cross-validation scores:", cv_scores_svm)
print("SVM Average cross-validation score:", cv_scores_svm.mean())
# Out:
# SVM Cross-validation scores: [0.4955045 0.483     0.466     0.509     0.504    ]
# SVM Average cross-validation score: 0.49150089910089906

# %%
# Confusion Matrix
kt_20_cm_svm = confusion_matrix(y_test, y_pred_svm)
plt.figure(figsize=(8, 6))
sns.heatmap(kt_20_cm_svm, annot=True, fmt='d', cmap='Blues',
            xticklabels=np.unique(y_test), yticklabels=np.unique(y_test))
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for SVM')
plt.show()

# %%
result = permutation_importance(svm_classifier, X_test, y_test, n_repeats=10, random_state=kt_20_random_state)

# Get feature importances
importances = result.importances_mean

# Create a DataFrame for better visualization
feature_importance_df = pd.DataFrame({'Feature': X_test.columns, 'Importance': importances})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

importance_threshold = 0.01

# Filter for important features
important_features = feature_importance_df[feature_importance_df['Importance'] >= importance_threshold]

print("Important features based on permutation importance (SVM):")
print(important_features)


# Example: Setting thresholds based on feature importance
for index, row in important_features.iterrows():
    feature_name = row['Feature']
    importance_value = row['Importance']

    if importance_value > 0.05:
        threshold = 0.7  # Example threshold value
        print(f"Feature '{feature_name}': High importance ({importance_value:.3f}), consider threshold > {threshold}")
    elif importance_value > 0.02:
        threshold = 0.5 # Example threshold value
        print(f"Feature '{feature_name}': Medium importance ({importance_value:.3f}), consider threshold > {threshold}")
    else:
        threshold = 0.2 # Example threshold value
        print(f"Feature '{feature_name}': Low importance ({importance_value:.3f}), consider threshold > {threshold}")
# Out:
# Important features based on permutation importance (SVM):
# Empty DataFrame
# Columns: [Feature, Importance]
# Index: []

# %% [markdown]
# ## Model Run Statistics

# %% [markdown]
# ### Time Taken and Memory Usage

# %%
import time
import tracemalloc

def get_model_run_stats(model, X_train, y_train, X_test):
    """Measures time and memory usage of a model's training and prediction."""

    start_time = time.time()
    tracemalloc.start()

    # Train the model
    model.fit(X_train, y_train)

    # Make predictions (optional, depending on what you want to time)
    model.predict(X_test)

    current, peak = tracemalloc.get_traced_memory()
    tracemalloc.stop()
    end_time = time.time()
    run_time = end_time - start_time

    return run_time, peak

models = {
    'KNN': knn_classifier,
    'Logistic Regression': logreg_classifier,
    # Add other models here
    'Decision Tree': dt_classifier,
    'Random Forest': rf_classifier,
    'SVM': svm_classifier
}


model_stats = {}
for model_name, model in models.items():
  run_time, peak_memory = get_model_run_stats(model, X_train, y_train, X_test)
  model_stats[model_name] = {'Time': run_time, 'Memory(bytes)': peak_memory}

# Print or store the statistics
for model_name, stats in model_stats.items():
    print(f"{model_name}: Time - {stats['Time']:.4f} seconds, Peak Memory - {stats['Memory(bytes)'] / (1024 * 1024):.2f} MB")
# Out:
# KNN: Time - 0.1729 seconds, Peak Memory - 0.49 MB
# Logistic Regression: Time - 0.0212 seconds, Peak Memory - 0.43 MB
# Decision Tree: Time - 0.0873 seconds, Peak Memory - 0.33 MB
# Random Forest: Time - 1.9711 seconds, Peak Memory - 0.58 MB
# SVM: Time - 0.8800 seconds, Peak Memory - 0.57 MB

# %% [markdown]
# --- End of Project ---
